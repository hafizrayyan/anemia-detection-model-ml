# %%
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv("anemia.csv")

# %%
df # 0 = male , 1 = female
# Out:
#       Gender  Hemoglobin   MCH  MCHC   MCV  Result
# 0          1        14.9  22.7  29.1  83.7       0
# 1          0        15.9  25.4  28.3  72.0       0
# 2          0         9.0  21.5  29.6  71.2       1
# 3          0        14.9  16.0  31.4  87.5       0
# 4          1        14.7  22.0  28.2  99.5       0
# ...      ...         ...   ...   ...   ...     ...
# 1416       0        10.6  25.4  28.2  82.9       1
# 1417       1        12.1  28.3  30.4  86.9       1
# 1418       1        13.1  17.7  28.1  80.7       1
# 1419       0        14.3  16.2  29.5  95.2       0
# 1420       0        11.8  21.2  28.4  98.1       1
#
# [1421 rows x 6 columns]

# %%
df.head()
# Out:
#    Gender  Hemoglobin   MCH  MCHC   MCV  Result
# 0       1        14.9  22.7  29.1  83.7       0
# 1       0        15.9  25.4  28.3  72.0       0
# 2       0         9.0  21.5  29.6  71.2       1
# 3       0        14.9  16.0  31.4  87.5       0
# 4       1        14.7  22.0  28.2  99.5       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1421 entries, 0 to 1420
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Gender      1421 non-null   int64
#  1   Hemoglobin  1421 non-null   float64
#  2   MCH         1421 non-null   float64
#  3   MCHC        1421 non-null   float64
#  4   MCV         1421 non-null   float64
#  5   Result      1421 non-null   int64
# dtypes: float64(4), int64(2)
# memory usage: 66.7 KB

# %%
df.isnull().sum()
# Out:
# Gender        0
# Hemoglobin    0
# MCH           0
# MCHC          0
# MCV           0
# Result        0
# dtype: int64

# %%
df.describe()
# Out:
#             Gender   Hemoglobin          MCH         MCHC          MCV  \
# count  1421.000000  1421.000000  1421.000000  1421.000000  1421.000000
# mean      0.520760    13.412738    22.905630    30.251232    85.523786
# std       0.499745     1.974546     3.969375     1.400898     9.636701
# min       0.000000     6.600000    16.000000    27.800000    69.400000
# 25%       0.000000    11.700000    19.400000    29.000000    77.300000
# 50%       1.000000    13.200000    22.700000    30.400000    85.300000
# 75%       1.000000    15.000000    26.200000    31.400000    94.200000
# max       1.000000    16.900000    30.000000    32.500000   101.600000
#
#             Result
# count  1421.000000
# mean      0.436312
# std       0.496102
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(887)

# %%
df = df.drop_duplicates()

# %%
X = df.drop(["Result"] , axis = 1)
y = df['Result']

# %%
X
# Out:
#       Gender  Hemoglobin   MCH  MCHC    MCV
# 0          1        14.9  22.7  29.1   83.7
# 1          0        15.9  25.4  28.3   72.0
# 2          0         9.0  21.5  29.6   71.2
# 3          0        14.9  16.0  31.4   87.5
# 4          1        14.7  22.0  28.2   99.5
# ...      ...         ...   ...   ...    ...
# 946        0        11.8  21.2  28.4   98.1
# 1156       1        15.1  21.3  32.4  100.6
# 1160       1        14.8  19.5  32.2   72.1
# 1376       1        13.2  20.4  28.0   97.4
# 1396       1        13.0  26.0  31.4   82.8
#
# [534 rows x 5 columns]

# %%
y
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 946     1
# 1156    0
# 1160    0
# 1376    1
# 1396    1
# Name: Result, Length: 534, dtype: int64

# %%
X_train , X_test , y_train ,y_test = train_test_split(X,y , test_size = 0.3 , random_state = 44)

# %%
X_train
# Out:
#       Gender  Hemoglobin   MCH  MCHC    MCV
# 913        0        11.5  18.9  31.2   81.3
# 933        0        15.0  19.5  31.3   71.9
# 9          1        14.9  25.8  31.3   82.9
# 1376       1        13.2  20.4  28.0   97.4
# 621        1        11.5  18.5  31.5   72.2
# ...      ...         ...   ...   ...    ...
# 120        1        16.8  19.9  32.4   90.9
# 84         1        12.8  16.3  31.1  100.9
# 96         1        12.9  27.4  28.2   78.8
# 173        0        11.2  20.1  30.8   76.4
# 836        0        10.7  19.4  29.2   93.7
#
# [373 rows x 5 columns]

# %%
y_train
# Out:
# 913     1
# 933     0
# 9       0
# 1376    1
# 621     1
#        ..
# 120     0
# 84      1
# 96      1
# 173     1
# 836     1
# Name: Result, Length: 373, dtype: int64

# %%
log_reg = LogisticRegression()

# %%
log_reg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_train,log_reg.predict(X_train)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98       202
#            1       0.97      1.00      0.98       171
#
#     accuracy                           0.98       373
#    macro avg       0.98      0.99      0.98       373
# weighted avg       0.98      0.98      0.98       373

# %%
print(classification_report(y_test,log_reg.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98        85
#            1       0.99      0.97      0.98        76
#
#     accuracy                           0.98       161
#    macro avg       0.98      0.98      0.98       161
# weighted avg       0.98      0.98      0.98       161

# %%
X_test
# Out:
#      Gender  Hemoglobin   MCH  MCHC    MCV
# 516       0         9.1  21.3  29.4   94.2
# 373       0         9.9  16.7  30.0   78.4
# 93        0        16.5  27.6  29.3   77.8
# 898       0        13.1  27.0  32.4   97.8
# 213       0        11.2  22.3  29.0  100.6
# ..      ...         ...   ...   ...    ...
# 469       1        13.0  28.1  31.6   94.6
# 724       1        12.9  25.7  29.7   80.6
# 573       1        12.4  24.8  29.6   93.4
# 33        0        11.0  17.0  29.5   75.3
# 207       1        11.8  24.3  32.0   80.6
#
# [161 rows x 5 columns]

# %%
y_test
# Out:
# 516    1
# 373    1
# 93     0
# 898    0
# 213    1
#       ..
# 469    1
# 724    1
# 573    1
# 33     1
# 207    1
# Name: Result, Length: 161, dtype: int64

# %%
import pickle

# %%
with open('anemia_pr_model.pkl',mode = 'wb') as f :
    pickle.dump(log_reg,f)
